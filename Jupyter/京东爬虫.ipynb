# %%
import requests

response = requests.get('https://item.jd.com/100005603522.html')
print(response.content)
# Out:
# b'<!DOCTYPE HTML>\n<html lang="zh-CN">\n<head>\n    <!-- shouji -->\n    <meta http-equiv="Content-Type" content="text/html; charset=gbk" />\n    <title>\xa1\xbe\xbb\xaa\xce\xaa\xc8\xd9\xd2\xab20\xa1\xbf\xc8\xd9\xd2\xab20 4800\xcd\xf2\xb3\xac\xb9\xe3\xbd\xc7AI\xcb\xc4\xc9\xe3 3200W\xc3\xc0\xd1\xd5\xd7\xd4\xc5\xc4 \xf7\xe8\xf7\xebKirin980\xc8\xab\xcd\xf8\xcd\xa8\xb0\xe68GB+128GB \xbb\xc3\xd2\xb9\xba\xda \xd2\xc6\xb6\xaf\xc1\xaa\xcd\xa8\xb5\xe7\xd0\xc54G\xc8\xab\xc3\xe6\xc6\xc1\xa1\xbe\xd0\xd0\xc7\xe9 \xb1\xa8\xbc\xdb \xbc\xdb\xb8\xf1 \xc6\xc0\xb2\xe2\xa1\xbf-\xbe\xa9\xb6\xab</title>\n    <meta name="keywords" content="HUAWEI\xc8\xd9\xd2\xab20,\xbb\xaa\xce\xaa\xc8\xd9\xd2\xab20,\xbb\xaa\xce\xaa\xc8\xd9\xd2\xab20\xb1\xa8\xbc\xdb,HUAWEI\xc8\xd9\xd2\xab20\xb1\xa8\xbc\xdb"/>\n    <meta name="description" content="\xa1\xbe\xbb\xaa\xce\xaa\xc8\xd9\xd2\xab20\xa1\xbf\xbe\xa9\xb6\xabJD.COM\xcc\xe1\xb9\xa9\xbb\xaa\xce\xaa\xc8\xd9\xd2\xab20\xd5\xfd\xc6\xb7\xd0\xd0\xbb\xf5\xa3\xac\xb2\xa2\xb0\xfc\
# ...

# %% [markdown]
# 安装BeautifulSoup：`pip3 install beautifulsoup4`

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(response.text,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="zh-CN">
#  <head>
#   <!-- shouji -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    【华为荣耀20】荣耀20 4800万超广角AI四摄 3200W美颜自拍 麒麟Kirin980全网通版8GB+128GB 幻夜黑 移动联通电信4G全面屏【行情 报价 价格 评测】-京东
#   </title>
#   <meta content="HUAWEI荣耀20,华为荣耀20,华为荣耀20报价,HUAWEI荣耀20报价" name="keywords"/>
#   <meta content="【华为荣耀20】京东JD.COM提供华为荣耀20正品行货，并包括HUAWEI荣耀20网购指南，以及华为荣耀20图片、荣耀20参数、荣耀20评论、荣耀20心得、荣耀20技巧等信息，网购华为荣耀20上京东,放心又轻松" name="description"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="format=xhtml; url=//item.m.jd.com/product/100005603522.html" http-equiv="mobile-agent"/>
#   <meta content="format=html5; url=//item.m.jd.com/product/100005603522.html" http-equiv="mobile-agent"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <link href="//item.jd.com/100005603522.html" rel="canonical"/>
#   <link href="//misc.360buyimg.com" rel="dns-prefetch"/>
# ...

# %%
ptable=soup.find(name='div',attrs={'class':'Ptable'})

# %%
ptable.find_all
